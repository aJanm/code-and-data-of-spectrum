# %%
# 绘制原始图
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
'''
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ccgl.csv', 'ctest6.csv' ]
'''

extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv']

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l']
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print("legend_list:",legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    print("x:", x)
    '''
    x: 0      350.0
    1      349.0
    2      348.0
    3      347.0
    4      346.0
        ...  
    156    194.0
    157    193.0
    158    192.0
    159    191.0
    160    190.0
    '''
    print("x[97]:",x[97],",x[112]:",x[112])
# 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Selected Range 7')

#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='ArialBlack', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='ArialBlack', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    # 2023年3月31日设置legend格式
    # 参考链接：https://blog.csdn.net/HsinglukLiu/article/details/107821714
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }
    plt.legend(loc=0, prop = font_legend)
    # plt.legend(loc=0, fontsize=12)
#     plt.show()
#     print(df)
# plt.grid()
plt.savefig('./光谱定性分析图/test.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# legend_list: ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l']
# final_path len: 10 , legend_list: 10
# x: 0      350.0
# 1      349.0
# 2      348.0
# 3      347.0
# 4      346.0
#        ...
# 156    194.0
# 157    193.0
# 158    192.0
# 159    191.0
# 160    190.0
# Name: nm, Length: 161, dtype: float64
# x[97]: 253.0 ,x[112]: 238.0
# x: 0      350.0
# 1      349.0
# 2      348.0
# 3      347.0
# 4      346.0
#        ...
# 156    194.0
# 157    193.0
# 158    192.0
# 159    191.0
# 160    190.0
# Name: nm, Length: 161, dtype: float64
# x[97]: 253.0 ,x[112]: 238.0
# x: 0      350.0
# 1      349.0
# 2      348.0
# 3      347.0
# 4      346.0
#        ...
# 156    194.0
# 157    193.0
# 158    192.0
# 159    191.0
# 160    190.0
# Name: nm, Length: 161, dtype: float64
# x[97]: 253.0 ,x[112]: 238.0
# x: 0      350.0
# 1      349.0
# 2      348.0
# 3      347.0
# ...

# %%
# 绘制原始图以及带其他数据的光谱图
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题

def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ctest1.csv', 'ccgl.csv', "cgllg.csv", "cyb.csv" ]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', 
'No1', "No2", "No3", "No4"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))

for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    
# 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        print("x[97]:",x[97],",x[112]:",x[112])
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Range 7')

#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='Times New Roman', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='Times New Roman', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i == 11:
        plt.plot(x, y, color="red", label=legend_list[i], linestyle='-.')
    elif i == 12:
        plt.plot(x, y, color="green", label=legend_list[i], linestyle='-.')
    elif i == 13:
        plt.plot(x, y, color="blue", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    } 
    plt.legend(loc=0, prop=font_legend)
#     plt.show()
#     print(df)
# plt.grid()
# plt.tight_layout()
# plt.savefig('./cod_sample4.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'No1', 'No2', 'No3', 'No4']
# final_path len: 14 , legend_list: 14
# x[97]: 253.0 ,x[112]: 238.0
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# ...

# %%
# 绘制原始图以及带其他数据的光谱图
# 尝试更改图片大小 2023年4月1日
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题

def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'E:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ctest1.csv', 'ccgl.csv', "cgllg.csv", "cyb.csv" ]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', 
'No1', "No2", "No3", "No4"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
plt.figure(figsize=(6.5,5.3)) # 先宽度后高度
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'weight' : 'normal',
        'size' : 26,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='Times New Roman', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='Times New Roman', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i == 11:
        plt.plot(x, y, color="red", label=legend_list[i], linestyle='-.')
    elif i == 12:
        plt.plot(x, y, color="green", label=legend_list[i], linestyle='-.')
    elif i == 13:
        plt.plot(x, y, color="blue", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    } 
    plt.legend(loc=0, prop=font_legend)
#     plt.show()
#     print(df)
# plt.grid()
# plt.tight_layout()
plt.savefig('./光谱定性分析图/cod_sample_total4.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# E:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'No1', 'No2', 'No3', 'No4']
# final_path len: 14 , legend_list: 14

# %%
# 尝试调节大小
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'E:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623T'
# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
extra_path = ['T10_1.csv','T20.csv', 'T30.csv', 'T40.csv', 'T50.csv',  'T60.csv','T70.csv','T80.csv','T90.csv','T100.csv']
# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l',  '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l','100mg/l']
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
# 2023年3月31日
# plt.figure(figsize=(7, 6)) # 先宽度后高度
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['T%']
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
#     y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
#     ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("T(%)", font)
    # 修改坐标轴字体及大小
    plt.yticks(fontproperties='Times New Roman', size=18)#设置大小及加粗
    plt.xticks(fontproperties='Times New Roman', size=18)
    # plt.yticks(fontproperties='Times New Roman', size=18,weight='bold')#设置大小及加粗
    # plt.xticks(fontproperties='Times New Roman', size=18,weight='bold')
#     plt.x_ticks(x_ticks)
    '''
    '-'       solid line style
    '--'      dashed line style
    '-.'      dash-dot line style
    ':'       dotted line style
    '''
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
        
        
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }    
    plt.legend(loc=0, prop=font_legend)
#     plt.show()
#     print(df)
# plt.grid()
plt.savefig('./光谱定性分析图/touguolv.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# E:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623T\T10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l']

# %%
import matplotlib    
print(matplotlib.matplotlib_fname())
# Out:
# d:\Program Files\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
# 绘制其他水样图 2023年4月1日
# 水样5 对应ctest7
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
'''
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ccgl.csv', 'ctest6.csv' ]
'''

extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv',
'c80.csv','c90.csv', 'c100.csv', "ctest7.csv"]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l',
'70mg/l','80mg/l','90mg/l', '100mg/l', "No5"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    # 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        print("x[97]:",x[97],",x[112]:",x[112])
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Range 7')
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='ArialBlack', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='ArialBlack', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    # 2023年3月31日设置legend格式
    # 参考链接：https://blog.csdn.net/HsinglukLiu/article/details/107821714
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }
    plt.legend(loc=0, prop = font_legend)
    # plt.legend(loc=0, fontsize=12)
#     plt.show()
#     print(df)
# plt.grid()

# 重要：写入图片时记得打开
# plt.savefig('./光谱定性分析图/ctest4_csv_水样6.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'No5']
# final_path len: 11 , legend_list: 11
# x[97]: 253.0 ,x[112]: 238.0
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# ...

# %%
# 绘制其他水样图 2023年4月1日
# 水样7对应ctest5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
'''
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ccgl.csv', 'ctest6.csv' ]
'''

extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv',
'c80.csv','c90.csv', 'c100.csv', "ctest5.csv"]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l',
'70mg/l','80mg/l','90mg/l', '100mg/l', "ctest5"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    # 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        print("x[97]:",x[97],",x[112]:",x[112])
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Range 7')
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='ArialBlack', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='ArialBlack', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    # 2023年3月31日设置legend格式
    # 参考链接：https://blog.csdn.net/HsinglukLiu/article/details/107821714
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }
    plt.legend(loc=0, prop = font_legend)
    # plt.legend(loc=0, fontsize=12)
#     plt.show()
#     print(df)
# plt.grid()
# plt.savefig('./光谱定性分析图/test.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'ctest5']
# final_path len: 11 , legend_list: 11
# x[97]: 253.0 ,x[112]: 238.0
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# ...

# %%
# 绘制其他水样图 2023年4月1日
# 水样6 对应ctest4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
'''
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ccgl.csv', 'ctest6.csv' ]
'''

extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv',
'c80.csv','c90.csv', 'c100.csv', "ctest4.csv"]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l',
'70mg/l','80mg/l','90mg/l', '100mg/l', "No6"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    # 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        print("x[97]:",x[97],",x[112]:",x[112])
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Range 7')
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='ArialBlack', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='ArialBlack', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    # 2023年3月31日设置legend格式
    # 参考链接：https://blog.csdn.net/HsinglukLiu/article/details/107821714
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }
    plt.legend(loc=0, prop = font_legend)
    # plt.legend(loc=0, fontsize=12)
#     plt.show()
#     print(df)
# plt.grid()

# 重要：写入图片时记得打开
# plt.savefig('./光谱定性分析图/ctest4_csv_水样6.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'No6']
# final_path len: 11 , legend_list: 11
# x[97]: 253.0 ,x[112]: 238.0
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# ...

# %%
# 绘制其他水样图 2023年4月1日
# 论文水样7 对应ctest5.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 这个类用于设置刻度间隔
from matplotlib.pyplot import MultipleLocator 
from pylab import *
# 路径拼接
import os

# 中文显示
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体（解决中文无法显示的问题）
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像时负号“-”显示方块的问题



def path_join(_base_path, _extra_path):

    base_path = _base_path
    extra_path = _extra_path
    final_path = []
    for i in range(len(extra_path)): 
    # for i in extra_path:
        tmp = os.path.join(base_path, extra_path[i])
        if i == 0:
            print(tmp)
            print(type(tmp))
        final_path.append(tmp)
    return final_path
base_path = r'D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置'
# ctest1.csv ctest2.csv ctest3.csv ctest4.csv
# ctest1的效果和ccgl很像, ctest2吸收度在0.75左右， ctest3浓度在10左右，将其设为水样2，ctest4浓度接近15将其设为水样3
# ctest5接近20mg/l, 将其设为水样4  ctest6和test4类似, ctest7约为10mg/l

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv', 'c100.csv', 'c120.csv', 'c140.csv', 'c160.csv', 'ccgl.csv', 'cgllg.csv', 'ctest.csv', 'ctest2.csv', 'ctest3.csv']
# extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 'c50.csv',  'c60.csv','c70.csv','c80.csv','c90.csv','c100.csv', 'ccgl.csv', 'cgllg.csv','cyb.csv', 'ctest1.csv', 'ctest2.csv', 'ctest3.csv', 'ctest5_浓度10_15.csv']
'''
extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv','c80.csv','c90.csv', 'c100.csv', 
'ccgl.csv', 'ctest6.csv' ]
'''

extra_path = ['c10_1.csv','c20_1.csv', 'c30_1.csv', 'c40.csv', 
'c50.csv',  
'c60.csv','c70.csv',
'c80.csv','c90.csv', 'c100.csv', "ctest5.csv"]

# extra_path = ['c20.csv', 'c40.csv', 'c60.csv', 'c80.csv']
final_path = path_join(base_path, extra_path)
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l']
# 第11种为对应的水样
# legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
# '50mg/l', '60mg/l','70mg/l','80mg/l','90mg/l', '100mg/l', '水样4', 'ctest']
legend_list = ['10mg/l', '20mg/l', '30mg/l', '40mg/l', 
'50mg/l', '60mg/l',
'70mg/l','80mg/l','90mg/l', '100mg/l', "No7"]
# legend_list = ['20mg/l', '40mg/l', '60mg/l', '80mg/l', '100mg/l', '120mg/l', '140mg/l', '160mg/l', 'ccgl', 'cgllg', 'ctest', 'ctest2', 'ctest3']
print(legend_list)
print("final_path len:", len(final_path), ", legend_list:", len(legend_list))
for i in range(len(final_path)):
    df = pd.read_csv(final_path[i])
    x = df['nm']
    y = df['Abs']
    # 2023年7月23日将第七个波段高亮显示,只绘制一次
    if i == 0:
        print("x[97]:",x[97],",x[112]:",x[112])
        selected_range_start = 97
        selected_range_end = 112
        plt.axvspan(x[selected_range_start], x[selected_range_end], color='green', alpha=0.3, label='Range 7')
#     print(x)
#     x_ticks = np.arange(len(x), 8)
    x_major_locator = MultipleLocator(30)
    y_major_locator = MultipleLocator(0.5)
    ax = plt.gca()
    ax.xaxis.set_major_locator(x_major_locator)
    ax.yaxis.set_major_locator(y_major_locator)
    plt.xlim(190, 350)
    font = {
        'family':'ArialBlack',
        'weight' : 'normal',
        'size' : 20,
    }
    plt.xlabel("Wavelength/nm", font)
    plt.ylabel("Absorbance", font)
#     plt.x_ticks(x_ticks)
#     plt.plot(x, y, label=legend_list[i])
    plt.yticks(fontproperties='ArialBlack', size=18,weight='bold')#设置大小及加粗
    plt.xticks(fontproperties='ArialBlack', size=18,weight='bold')
    if i == 0:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 9:
        plt.plot(x, y, label=legend_list[i], linestyle='-')
    elif i == 10:
        plt.plot(x, y, color="black", label=legend_list[i], linestyle='-.')
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (3,5,1,5)))
    elif i % 3 == 1:
        plt.plot(x, y, label=legend_list[i], linestyle='-.')
    elif i % 3 == 2:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5, 5))) # 间距较大的两段虚线
    elif i % 3 == 0:
        plt.plot(x, y, label=legend_list[i], linestyle=(0, (5,10)))
    # 2023年3月31日设置legend格式
    # 参考链接：https://blog.csdn.net/HsinglukLiu/article/details/107821714
    font_legend = {
        'family':'ArialBlack',
        'weight':'bold',
        'size':11,
    }
    plt.legend(loc=0, prop = font_legend)
    # plt.legend(loc=0, fontsize=12)
#     plt.show()
#     print(df)
# plt.grid()

# 重要：写入图片时记得打开
# plt.savefig('./光谱定性分析图/ctest5_csv_水样7.svg', bbox_inches='tight')
plt.show()
# 分析结果
# 在290左右有一个吸收峰
# Out:
# D:\大学\学习\研\研究生科研\论文学习\论文阅读\zj\20220623新配置\c10_1.csv
# <class 'str'>
# ['10mg/l', '20mg/l', '30mg/l', '40mg/l', '50mg/l', '60mg/l', '70mg/l', '80mg/l', '90mg/l', '100mg/l', 'No7']
# final_path len: 11 , legend_list: 11
# x[97]: 253.0 ,x[112]: 238.0
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# findfont: Font family 'ArialBlack' not found.
# ...
